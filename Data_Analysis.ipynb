# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
#Dropping the unwanted columns from the dataframe.
diwali_df.drop(['Status', 'unnamed1'], axis=1, inplace=True)

# %%
diwali_df
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0      1002903    Sanskriti  P00125942      F     26-35   28               0
# 1      1000732       Kartik  P00110942      F     26-35   35               1
# 2      1001990        Bindu  P00118542      F     26-35   35               1
# 3      1001425       Sudevi  P00237842      M      0-17   16               0
# 4      1000588         Joni  P00057942      M     26-35   28               1
# ...        ...          ...        ...    ...       ...  ...             ...
# 11246  1000695      Manning  P00296942      M     18-25   19               1
# 11247  1004089  Reichenbach  P00171342      M     26-35   33               0
# 11248  1001209        Oshin  P00201342      F     36-45   40               0
# 11249  1004023       Noonan  P00059442      M     36-45   37               0
# 11250  1002744      Brumley  P00281742      F     18-25   19               0
#
# ...

# %%
#Counting the number of null values in every column
diwali_df.isnull().sum()
# Out:
# User_ID              0
# Cust_name            0
# Product_ID           0
# Gender               0
# Age Group            0
# Age                  0
# Marital_Status       0
# State                0
# Zone                 0
# Occupation           0
# Product_Category     0
# Orders               0
# Amount              12
# dtype: int64

# %%
#Filtering the rows with null values
diwali_df[diwali_df.Amount.isnull() == True]
# Out:
#      User_ID Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 7    1002092  Shivangi  P00273442      F       55+   61               0
# 14   1003858      Cano  P00293742      M     46-50   46               1
# 16   1005447       Amy  P00275642      F     46-50   48               1
# 109  1005265    Sakshi  P00296242      F     46-50   48               1
# 111  1005261   Apoorva  P00057942      F     36-45   41               1
# 184  1005538    Kartik  P00269542      F     46-50   49               1
# 293  1000326  Jonathan  P00120542      M     51-55   53               0
# 344  1002507   Lakshmi  P00045842      F     26-35   35               1
# 345  1004498   Srishti  P00030842      F     51-55   55               0
# 452  1004601    Gaurav  P00014442      F     36-45   40               1
# 464  1004528    Anurag  P00338442      F     26-35   33               1
# 493  1002994    Hemant   P0009942      F     36-45   38               0
#
# ...

# %%
#Deleting the rows with null values
diwali_df.dropna(inplace=True)

# %%
diwali_df[diwali_df.Amount.isnull() == True]
diwali_df.isnull().sum()
# Out:
# User_ID             0
# Cust_name           0
# Product_ID          0
# Gender              0
# Age Group           0
# Age                 0
# Marital_Status      0
# State               0
# Zone                0
# Occupation          0
# Product_Category    0
# Orders              0
# Amount              0
# dtype: int64

# %%
#Changing the data type if required.
diwali_df['Amount'] = diwali_df['Amount'].astype('int')
diwali_df.Amount.dtype #Successfully converted
# Out:
# dtype('int32')

# %%
diwali_df.dtypes
# Out:
# User_ID              int64
# Cust_name           object
# Product_ID          object
# Gender              object
# Age Group           object
# Age                  int64
# Marital_Status       int64
# State               object
# Zone                object
# Occupation          object
# Product_Category    object
# Orders               int64
# Amount               int32
# dtype: object

# %%
diwali_df.describe()
# Out:
#             User_ID           Age  Marital_Status        Orders        Amount
# count  1.123900e+04  11239.000000    11239.000000  11239.000000  11239.000000
# mean   1.003004e+06     35.410357        0.420055      2.489634   9453.610553
# std    1.716039e+03     12.753866        0.493589      1.114967   5222.355168
# min    1.000001e+06     12.000000        0.000000      1.000000    188.000000
# 25%    1.001492e+06     27.000000        0.000000      2.000000   5443.000000
# 50%    1.003064e+06     33.000000        0.000000      2.000000   8109.000000
# 75%    1.004426e+06     43.000000        1.000000      3.000000  12675.000000
# max    1.006040e+06     92.000000        1.000000      4.000000  23952.000000

# %% [markdown]
# Exploratory Data Analysis

# %%
#Count by Gender

ax = sns.countplot(x = 'Gender', data=diwali_df, hue='Gender')

for bars in ax.containers:
    ax.bar_label(bars)

# %%
#Sales by Gender

sales_gen = diwali_df.groupby(['Gender'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)
sales_gen
sns.barplot(x='Gender', y='Amount', data=sales_gen, hue='Gender');

# %% [markdown]
# From the above graphs, it can be said that most of the buyers are females and the purchasing power of females are greater than men as well.

# %%
#Age

ax = sns.countplot(x='Age Group', data=diwali_df, hue='Gender')

for bars in ax.containers:
    ax.bar_label(bars)

# %%
sales_agegroup = diwali_df.groupby(['Age Group'],as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)

sns.barplot(x='Age Group', y='Amount', data=sales_agegroup, hue='Age Group')
# Out:
# <Axes: xlabel='Age Group', ylabel='Amount'>

# %% [markdown]
# From the above the graphs, it can be said that most of the buyers fall under the age group 26-35 years old females

# %%
diwali_df
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0      1002903    Sanskriti  P00125942      F     26-35   28               0
# 1      1000732       Kartik  P00110942      F     26-35   35               1
# 2      1001990        Bindu  P00118542      F     26-35   35               1
# 3      1001425       Sudevi  P00237842      M      0-17   16               0
# 4      1000588         Joni  P00057942      M     26-35   28               1
# ...        ...          ...        ...    ...       ...  ...             ...
# 11246  1000695      Manning  P00296942      M     18-25   19               1
# 11247  1004089  Reichenbach  P00171342      M     26-35   33               0
# 11248  1001209        Oshin  P00201342      F     36-45   40               0
# 11249  1004023       Noonan  P00059442      M     36-45   37               0
# 11250  1002744      Brumley  P00281742      F     18-25   19               0
#
# ...

# %%
#Most number of orders from top 10 states

Orders_state = diwali_df.groupby(['State'], as_index=False)['Orders'].sum().sort_values(by='Orders', ascending=False).head(10)
plt.figure(figsize=(15,9))

sns.barplot(data=Orders_state, x='State', y='Orders', hue='State')
# Out:
# <Axes: xlabel='State', ylabel='Orders'>

# %%
#Total Amount of Sales from top 10 states
sales_state = diwali_df.groupby(['State'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False).head(10)
plt.figure(figsize=(15,9))

sns.barplot(data=sales_state, x='State', y='Amount', hue='State')
# Out:
# <Axes: xlabel='State', ylabel='Amount'>

# %% [markdown]
# From the above graphs, it appears that most of the orders placed and sales generated are from the states of Uttar Pradesh, Maharashtra and Karnataka.

# %%
diwali_df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount'],
#       dtype='object')

# %%
#Marital Status
ax = sns.countplot(data=diwali_df, x='Marital_Status', hue='Marital_Status')


for bars in ax.containers:
    ax.bar_label(bars)

# %%
sales_marital_status = diwali_df.groupby(['Marital_Status', 'Gender'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)

ax = sns.barplot(data=sales_marital_status, x = 'Marital_Status', y='Amount', hue='Gender')

# %% [markdown]
# From the above graphs, it appears that most of the buyers are married women and they have higher purchasing power

# %%
#Occupation
plt.figure(figsize=(20, 8))
ax = sns.countplot(data=diwali_df, x='Occupation', hue='Occupation')

for bars in ax.containers:
    ax.bar_label(bars)

# %%
#Occupatation
plt.figure(figsize=(20, 8))
Sales_Occupation = diwali_df.groupby(['Occupation'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)


sns.barplot(data=Sales_Occupation, x='Occupation', y='Amount', hue='Occupation')
# Out:
# <Axes: xlabel='Occupation', ylabel='Amount'>

# %% [markdown]
# From the above graphs, it can be seen that most buyers are working in IT, Healthcare and Aviation sectors.

# %%
# Product Category
plt.figure(figsize=(40, 12))
ax = sns.countplot(data=diwali_df, x='Product_Category', hue='Product_Category')

for counts in ax.containers:
    ax.bar_label(counts)

# %%
Sales_Product_Category = diwali_df.groupby(['Product_Category'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False).head(10)
Sales_Product_Category

plt.figure(figsize=(19, 8))
sns.barplot(data=Sales_Product_Category, x='Product_Category', y='Amount', hue='Product_Category')
# Out:
# <Axes: xlabel='Product_Category', ylabel='Amount'>

# %% [markdown]
# Conclustion:

# %% [markdown]
# Married women in the age group 26-35 years residing in Uttar Pradesh, Maharashtra, and Karnataka, working in the IT, Healthcare, and Aviation sectors, are more likely to be interested in purchasing products from the Food, Clothing, and Electronics categories.
